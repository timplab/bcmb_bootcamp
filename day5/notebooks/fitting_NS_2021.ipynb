# %% [markdown]
# # Interpolating and Extrapolating

# %% [markdown]
# So - we can now generate models and solve equations, but what if we are measuring data?
#
# First - let's talk about _interpolation_ and _extrapolation_.
#
# **_Interpolation_** is estimating values between recorded data points.
# **_Extrapolation_** is istimating outside the bounds of the recorded data.
#
# We can do both of these with python!
#
# First let's generate some example "data" to play with. We are going to make this up, but you could use real data just as easily after loading it with - say - pandas, etc.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_x=np.linspace(0, 10, 11)
data_y=np.cos(-data_x**2/9.0)

# %%
plt.plot(data_x, data_y, 'ro')

# %% [markdown]
# Now let's try to interpolate between the data points. From `scipy` yet again, we can use the `interp1d` function, which generates an "interpolation function object" - basically a function you can pass values to to see what they would be.

# %%
from scipy.interpolate import interp1d

# %%
f_linear=interp1d(data_x, data_y)

# %% [markdown]
# Let's make a denser set of x points so we can see how the interpolation is working.

# %%
dense_x=np.linspace(0, 10, 51)

# %% [markdown]
# Then let's apply the interpolation function

# %%
y_linear=f_linear(dense_x)
y_linear
# Out:
# array([ 1.        ,  0.9987667 ,  0.9975334 ,  0.99630011,  0.99506681,
#         0.99383351,  0.97563674,  0.95743997,  0.93924321,  0.92104644,
#         0.90284967,  0.8303402 ,  0.75783072,  0.68532125,  0.61281178,
#         0.54030231,  0.3911405 ,  0.2419787 ,  0.09281689, -0.05634492,
#        -0.20550672, -0.3513146 , -0.49712249, -0.64293037, -0.78873825,
#        -0.93454613, -0.87836563, -0.82218513, -0.76600463, -0.70982412,
#        -0.65364362, -0.38923492, -0.12482621,  0.13958249,  0.4039912 ,
#         0.6683999 ,  0.67000091,  0.67160191,  0.67320291,  0.67480392,
#         0.67640492,  0.35889788,  0.04139085, -0.27611619, -0.59362323,
#        -0.91113026, -0.70584822, -0.50056618, -0.29528414, -0.09000209,
#         0.11527995])

# %% [markdown]
# And plot!

# %%
plt.plot(data_x, data_y, 'ro')
plt.plot(dense_x, y_linear, 'b-')

# %% [markdown]
# Ok - so the basic interp1d just draws a straight line between each data point, and uses that to figure out what a new y-value might be.  This is . . . useful, but one could clearly suspect that it's not accurate.  If we look at what the actual data formula would have generated:

# %%
dense_y=np.cos(-dense_x**2/9.0)

# %%
plt.plot(data_x, data_y, 'ro')
plt.plot(dense_x, y_linear, 'b-')
plt.plot(dense_x, dense_y, 'r--')

# %% [markdown]
# It's ok in certain regions, but in others is way off.  What happens if we try to _extrapolate_ or plot values outside the range of the initial data?

# %%
extra_x=np.linspace(-2, 12, 71)
y_linear_extra=f_linear(extra_x) #this will throw an error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-406a61fc4b35> in <module>
#       1 extra_x=np.linspace(-2, 12, 71)
# ----> 2 y_linear_extra=f_linear(extra_x) #this will throw an error
#
# NameError: name 'f_linear' is not defined

# %% [markdown]
# Hmm - threw an error!  Reading the error - it says `A value in x_new is below the interpolation range.` - meaning that we tried to extrapolate.  However, there are _options_ you can set for `interp1d` that will allow the function to extrapolate.  These options are `bounds_error` and `fill_value`.
#
# `bounds_error` controls whether this error is thrown, but if you specify it as `False` you must also specify the `fill_value`.  `fill_value` can either be the values you want to "fill" in when extrapolating as in (.5, -.5):

# %%
f_linear_fixed=interp1d(data_x, data_y, bounds_error=False, fill_value=(.5, -.5))
y_linear_fixed=f_linear_fixed(extra_x)

# %%
plt.plot(data_x, data_y, 'ro')
plt.plot(extra_x, y_linear_fixed, 'b-')

# %% [markdown]
# So it just uses a constant value outside the bounds of the data that was specified. The other option for `fill_value` is to say "extrapolate"

# %%
f_linear_extra=interp1d(data_x, data_y, bounds_error=False, fill_value="extrapolate")
y_linear_extra=f_linear_extra(extra_x)

# %%
plt.plot(data_x, data_y, 'ro')
plt.plot(extra_x, y_linear_extra, 'b-')

# %% [markdown]
# So with extrapolate it just continues the line defined from the last two points.
#
# We can also set the `kind` of interpolation we are doing - the default interpolation is "linear", but we can also do one of a couple different spline fits:

# %%
f_zero=interp1d(data_x, data_y, 'zero')
f_slinear=interp1d(data_x, data_y, kind='slinear')
f_cubic=interp1d(data_x, data_y, kind='cubic')

# %%
y_zero=f_zero(dense_x)
y_slinear=f_slinear(dense_x)
y_cubic=f_cubic(dense_x)

# %%
plt.plot(data_x, data_y, 'ro')
plt.plot(dense_x, y_zero, 'b-')
plt.plot(dense_x, y_slinear, 'r--')
plt.plot(dense_x, y_cubic, 'k-+')
plt.legend(['data', 'Zeroth order', 'first order', 'second order'])

# %% [markdown]
# Or we can try `nearest`, `previous` or `next`:

# %%
f_nearest=interp1d(data_x, data_y, 'nearest')
f_previous=interp1d(data_x, data_y, kind='previous')
f_next=interp1d(data_x, data_y, kind='next')

# %%
y_nearest=f_nearest(dense_x)
y_previous=f_previous(dense_x)
y_next=f_next(dense_x)

# %%
plt.plot(data_x, data_y, 'ro')
plt.plot(dense_x, y_nearest, 'b-')
plt.plot(dense_x, y_previous, 'r--')
plt.plot(dense_x, y_next, 'k-+')
plt.legend(['data', 'nearest', 'previous', 'next'])

# %% [markdown]
# ## Curve fitting

# %% [markdown]
# So - we can intperolate between points - but what if we want to fig a curve to the whole function?
#
# We can use `curve_fit` from `scipy.optimize`
#
# Let's make some noisy "data" to test our fitting:

# %%
x=np.linspace(0.0,20.0,51)
A=5.0
y=A*np.sin(x)+np.random.normal(size=51)

# %%
plt.plot(x,y, 'ro')

# %% [markdown]
# So with this data, let's try to fit a sin curve.

# %%
from scipy import optimize

# %% [markdown]
# Now we have to setup the function we want to fit, and what parameters it has:

# %%
def myequation(x, a, b):
    y=a*np.sin(x*b)
    return y

# %%
param, param_covar = optimize.curve_fit(myequation, x, y)
param
# Out:
# array([5.02628839, 1.00265248])

# %%
y_fit=myequation(x, param[0], param[1])

# %%
plt.plot(x,y, 'ro')
plt.plot(x,y_fit, 'b--')

# %% [markdown]
# Ok - let's pull in some real data!  From here <https://pdixon.stat.iastate.edu/stat511/datasets.html> we've pulled a tab separated file for you looking at some enzyme kinetics!
#
# You are probably all familiar with the justifiably famous Michaelis-Menten equation:
#
# $V = \frac{V_{max} [S]}{K_M + [S]}$
#
# that enzyme kinetics follow.  Let's fit our data to equation so we can extract the parameters.

# %%
import pandas as pd
import plotnine as p9

# %%
enzyme=pd.read_table("~/bcmb_bootcamp-2021/day5/data/enzyme.txt")
enzyme
# Out:
#     velocity  concentration
# 0        2.1            1.0
# 1        2.5            1.5
# 2        4.9            2.0
# 3        5.5            3.0
# 4        7.0            4.0
# 5        8.4            5.0
# 6        9.6            6.0
# 7       10.2            7.5
# 8       11.4            8.5
# 9       12.5           10.0
# 10      13.1           12.5
# 11      14.6           15.0
# 12      17.0           17.5
# 13      16.8           20.0
# 14      18.6           25.0
# 15      19.7           30.0
# 16      21.3           35.0
# 17      21.6           40.0

# %%
plt.plot(enzyme.concentration, enzyme.velocity, 'ro')

# %% [markdown]
# Now let's set up the equation:

# %%
def michaelis_menten(s, v_max, k_m):
    v=v_max*s/(k_m+s)
    return v

# %%
enz_param, enz_param_covar = optimize.curve_fit(michaelis_menten, enzyme.concentration, enzyme.velocity)
enz_param
# Out:
# array([28.1370453 , 12.57444821])

# %%
fit_velocity=michaelis_menten(enzyme.concentration, enz_param[0], enz_param[1])

# %%
plt.plot(enzyme.concentration, enzyme.velocity, 'ro')
plt.plot(enzyme.concentration, fit_velocity, 'b--')

# %% [markdown]
# Pretty nice fit!  So we have used this to figure out what the parameters are for the enzyme.  Of course you could have also generated a Lineweaver-Burk plot - but I think the point is that _if_ you can setup an equation with the parameters, and you have sufficient data, you can try to fit it.

# %% [markdown]
# Now let's look at the pharmacokinetics of cefamandole. Cefamandole is a broad-spectrum antibiotic (no longer used in the US).  This data represents 6 healthy volunteers injected with 15 mg/kg body mass of cefamandole, then the plasma concentrations of the drug were measured at 14 time points.
#
# Your friendly neighborhood biochemist told you that there are _two_ different rates involved in the degradation of this molecule, renal clearance and non-renal <https://www.ncbi.nlm.nih.gov/pmc/articles/PMC155817/>:
#
# $\frac{d[C]}{dt} = -{renal}[C] - {nonrenal}[C]$

# %%
cefa=pd.read_csv("~/bcmb_bootcamp-2021/day5/data/cefamandole.csv")
cefa
# Out:
#     Unnamed: 0  Subject  Time    conc
# 0            1        1    10  127.00
# 1            2        1    15   80.00
# 2            3        1    20   47.40
# 3            4        1    30   39.90
# 4            5        1    45   24.80
# ..         ...      ...   ...     ...
# 79          80        6   150    8.80
# 80          81        6   180    6.00
# 81          82        6   240    3.00
# 82          83        6   300    1.30
# 83          84        6   360    1.03
#
# [84 rows x 4 columns]

# %%
#edit our dataframe to remove unnecessary columns
cefa_edited = cefa.drop(cefa.columns[cefa.columns.str.contains('unnamed',case = False)])
cefa_edited
# Out:
#     Subject  Time    conc
# 0         1    10  127.00
# 1         1    15   80.00
# 2         1    20   47.40
# 3         1    30   39.90
# 4         1    45   24.80
# ..      ...   ...     ...
# 79        6   150    8.80
# 80        6   180    6.00
# 81        6   240    3.00
# 82        6   300    1.30
# 83        6   360    1.03
#
# [84 rows x 3 columns]

# %%
(p9.ggplot(data=cefa, mapping=p9.aes(x='Time', y='conc', color='Subject')) + p9.geom_point())
# Out:
# <ggplot: (8731644313706)>

# %% [markdown]
# So - now we can either use the analytical exponential that we expect from this:
#
# $[C] = C_0 e^{-(renal+nonrenal)t}$
#
# Or we can generate the ODE as we did in the previous unit:

# %%
from scipy.integrate import solve_ivp

# %%
#turning our dataframe into a numpy array
cefa_array = cefa_edited.to_numpy()
cefa_array
# Out:
# array([[1.00e+00, 1.00e+01, 1.27e+02],
#        [1.00e+00, 1.50e+01, 8.00e+01],
#        [1.00e+00, 2.00e+01, 4.74e+01],
#        [1.00e+00, 3.00e+01, 3.99e+01],
#        [1.00e+00, 4.50e+01, 2.48e+01],
#        [1.00e+00, 6.00e+01, 1.79e+01],
#        [1.00e+00, 7.50e+01, 1.17e+01],
#        [1.00e+00, 9.00e+01, 1.09e+01],
#        [1.00e+00, 1.20e+02, 5.70e+00],
#        [1.00e+00, 1.50e+02, 2.55e+00],
#        [1.00e+00, 1.80e+02, 1.84e+00],
#        [1.00e+00, 2.40e+02, 1.50e+00],
#        [1.00e+00, 3.00e+02, 7.00e-01],
#        [1.00e+00, 3.60e+02, 3.40e-01],
#        [2.00e+00, 1.00e+01, 1.20e+02],
#        [2.00e+00, 1.50e+01, 9.01e+01],
#        [2.00e+00, 2.00e+01, 7.00e+01],
#        [2.00e+00, 3.00e+01, 4.01e+01],
#        [2.00e+00, 4.50e+01, 2.40e+01],
#        [2.00e+00, 6.00e+01, 1.61e+01],
#        [2.00e+00, 7.50e+01, 1.16e+01],
#        [2.00e+00, 9.00e+01, 9.20e+00],
#        [2.00e+00, 1.20e+02, 5.20e+00],
#        [2.00e+00, 1.50e+02, 3.00e+00],
#        [2.00e+00, 1.80e+02, 1.54e+00],
#        [2.00e+00, 2.40e+02, 7.30e-01],
#        [2.00e+00, 3.00e+02, 3.70e-01],
#        [2.00e+00, 3.60e+02, 1.90e-01],
#        [3.00e+00, 1.00e+01, 1.54e+02],
#        [3.00e+00, 1.50e+01, 9.40e+01],
#        [3.00e+00, 2.00e+01, 8.40e+01],
#        [3.00e+00, 3.00e+01, 5.60e+01],
#        [3.00e+00, 4.50e+01, 3.71e+01],
#        [3.00e+00, 6.00e+01, 2.89e+01],
#        [3.00e+00, 7.50e+01, 2.55e+01],
#        [3.00e+00, 9.00e+01, 2.00e+01],
#        [3.00e+00, 1.20e+02, 1.24e+01],
#        [3.00e+00, 1.50e+02, 8.30e+00],
#        [3.00e+00, 1.80e+02, 4.50e+00],
#        [3.00e+00, 2.40e+02, 3.40e+00],
#        [3.00e+00, 3.00e+02, 1.70e+00],
#        [3.00e+00, 3.60e+02, 1.19e+00],
#        [4.00e+00, 1.00e+01, 1.81e+02],
#        [4.00e+00, 1.50e+01, 1.19e+02],
#        [4.00e+00, 2.00e+01, 8.43e+01],
#        [4.00e+00, 3.00e+01, 5.61e+01],
#        [4.00e+00, 4.50e+01, 3.98e+01],
#        [4.00e+00, 6.00e+01, 2.33e+01],
#        [4.00e+00, 7.50e+01, 2.27e+01],
#        [4.00e+00, 9.00e+01, 1.30e+01],
#        [4.00e+00, 1.20e+02, 8.00e+00],
#        [4.00e+00, 1.50e+02, 2.40e+00],
#        [4.00e+00, 1.80e+02, 1.60e+00],
#        [4.00e+00, 2.40e+02, 1.10e+00],
#        [4.00e+00, 3.00e+02, 4.80e-01],
#        [4.00e+00, 3.60e+02, 2.90e-01],
#        [5.00e+00, 1.00e+01, 2.53e+02],
#        [5.00e+00, 1.50e+01, 1.76e+02],
#        [5.00e+00, 2.00e+01, 1.50e+02],
#        [5.00e+00, 3.00e+01, 9.03e+01],
#        [5.00e+00, 4.50e+01, 6.96e+01],
#        [5.00e+00, 6.00e+01, 4.25e+01],
#        [5.00e+00, 7.50e+01, 3.06e+01],
#        [5.00e+00, 9.00e+01, 1.96e+01],
#        [5.00e+00, 1.20e+02, 1.38e+01],
#        [5.00e+00, 1.50e+02, 1.14e+01],
#        [5.00e+00, 1.80e+02, 6.30e+00],
#        [5.00e+00, 2.40e+02, 3.80e+00],
#        [5.00e+00, 3.00e+02, 1.55e+00],
#        [5.00e+00, 3.60e+02, 1.22e+00],
#        [6.00e+00, 1.00e+01, 1.40e+02],
#        [6.00e+00, 1.50e+01, 1.20e+02],
#        [6.00e+00, 2.00e+01, 1.06e+02],
#        [6.00e+00, 3.00e+01, 6.04e+01],
#        [6.00e+00, 4.50e+01, 6.09e+01],
#        [6.00e+00, 6.00e+01, 4.22e+01],
#        [6.00e+00, 7.50e+01, 2.68e+01],
#        [6.00e+00, 9.00e+01, 2.20e+01],
#        [6.00e+00, 1.20e+02, 1.45e+01],
#        [6.00e+00, 1.50e+02, 8.80e+00],
#        [6.00e+00, 1.80e+02, 6.00e+00],
#        [6.00e+00, 2.40e+02, 3.00e+00],
#        [6.00e+00, 3.00e+02, 1.30e+00],
#        [6.00e+00, 3.60e+02, 1.03e+00]])

# %%
#Define our paramenters
t=np.array(cefa_array[:,:2]) #this has patient and time
C=np.array(cefa_array[:,::2]) #this has patient and concentration
###what are we defining renal and nonrenal as?
# Out:
# array([[1.00e+00, 1.27e+02],
#        [1.00e+00, 8.00e+01],
#        [1.00e+00, 4.74e+01],
#        [1.00e+00, 3.99e+01],
#        [1.00e+00, 2.48e+01],
#        [1.00e+00, 1.79e+01],
#        [1.00e+00, 1.17e+01],
#        [1.00e+00, 1.09e+01],
#        [1.00e+00, 5.70e+00],
#        [1.00e+00, 2.55e+00],
#        [1.00e+00, 1.84e+00],
#        [1.00e+00, 1.50e+00],
#        [1.00e+00, 7.00e-01],
#        [1.00e+00, 3.40e-01],
#        [2.00e+00, 1.20e+02],
#        [2.00e+00, 9.01e+01],
#        [2.00e+00, 7.00e+01],
#        [2.00e+00, 4.01e+01],
#        [2.00e+00, 2.40e+01],
#        [2.00e+00, 1.61e+01],
#        [2.00e+00, 1.16e+01],
#        [2.00e+00, 9.20e+00],
#        [2.00e+00, 5.20e+00],
#        [2.00e+00, 3.00e+00],
#        [2.00e+00, 1.54e+00],
#        [2.00e+00, 7.30e-01],
#        [2.00e+00, 3.70e-01],
#        [2.00e+00, 1.90e-01],
#        [3.00e+00, 1.54e+02],
#        [3.00e+00, 9.40e+01],
#        [3.00e+00, 8.40e+01],
#        [3.00e+00, 5.60e+01],
#        [3.00e+00, 3.71e+01],
#        [3.00e+00, 2.89e+01],
#        [3.00e+00, 2.55e+01],
#        [3.00e+00, 2.00e+01],
#        [3.00e+00, 1.24e+01],
#        [3.00e+00, 8.30e+00],
#        [3.00e+00, 4.50e+00],
#        [3.00e+00, 3.40e+00],
#        [3.00e+00, 1.70e+00],
#        [3.00e+00, 1.19e+00],
#        [4.00e+00, 1.81e+02],
#        [4.00e+00, 1.19e+02],
#        [4.00e+00, 8.43e+01],
#        [4.00e+00, 5.61e+01],
#        [4.00e+00, 3.98e+01],
#        [4.00e+00, 2.33e+01],
#        [4.00e+00, 2.27e+01],
#        [4.00e+00, 1.30e+01],
#        [4.00e+00, 8.00e+00],
#        [4.00e+00, 2.40e+00],
#        [4.00e+00, 1.60e+00],
#        [4.00e+00, 1.10e+00],
#        [4.00e+00, 4.80e-01],
#        [4.00e+00, 2.90e-01],
#        [5.00e+00, 2.53e+02],
#        [5.00e+00, 1.76e+02],
#        [5.00e+00, 1.50e+02],
#        [5.00e+00, 9.03e+01],
#        [5.00e+00, 6.96e+01],
#        [5.00e+00, 4.25e+01],
#        [5.00e+00, 3.06e+01],
#        [5.00e+00, 1.96e+01],
#        [5.00e+00, 1.38e+01],
#        [5.00e+00, 1.14e+01],
#        [5.00e+00, 6.30e+00],
#        [5.00e+00, 3.80e+00],
#        [5.00e+00, 1.55e+00],
#        [5.00e+00, 1.22e+00],
#        [6.00e+00, 1.40e+02],
#        [6.00e+00, 1.20e+02],
#        [6.00e+00, 1.06e+02],
#        [6.00e+00, 6.04e+01],
#        [6.00e+00, 6.09e+01],
#        [6.00e+00, 4.22e+01],
#        [6.00e+00, 2.68e+01],
#        [6.00e+00, 2.20e+01],
#        [6.00e+00, 1.45e+01],
#        [6.00e+00, 8.80e+00],
#        [6.00e+00, 6.00e+00],
#        [6.00e+00, 3.00e+00],
#        [6.00e+00, 1.30e+00],
#        [6.00e+00, 1.03e+00]])

# %%
def decay(t, C, renal, nonrenal):
    rate = -(renal * C) - (nonrenal * C)
    return rate

# %% [markdown]
# But then we still need a function to output the concentration for us:

# %%
def conc(t, renal, nonrenal, C_0):
    C_solver = solve_ivp(decay, [min(t), max(t)], C_0, t_eval=t)
    return C_solver.y

# %% [markdown]
# Let's fit each patient individually:

# %%
for patient in cefa.Subject.unique():
    thispatient=cefa[cefa.Subject==patient]
    enz_param, enz_param_covar = optimize.curve_fit(conc, thispatient.Time, thispatient.conc)
    print(patient+": ")
    print(enz_param)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-904c8ab95973> in <module>
#       7 for patient in cefa.Subject.unique():
#       8     thispatient=cefa[cefa.Subject==patient]
# ----> 9     enz_param, enz_param_covar = optimize.curve_fit(conc, thispatient.Time, thispatient.conc)
#      10     enz_param
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     782         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     783         return_full = kwargs.pop('full_output', False)
# --> 784         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     785         popt, pcov, infodict, errmsg, ier = res
#     786         ysize = len(infodict['fvec'])
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     408     if not isinstance(args, tuple):
#     409         args = (args,)
# --> 410     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     411     m = shape[0]
#     412
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/minpack.py in func_wrapped(params)
#     482     if transform is None:
#     483         def func_wrapped(params):
# --> 484             return func(xdata, *params) - ydata
#     485     elif transform.ndim == 1:
#     486         def func_wrapped(params):
#
# <ipython-input-25-ce23860e56c6> in conc(t, renal, nonrenal, C_0)
#       1 def conc(t, renal, nonrenal, C_0):
# ----> 2     C_solver = solve_ivp(decay, [min(t), max(t)], C_0, t_eval=t)
#       3     return C_solver.y
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     540         method = METHODS[method]
#     541
# --> 542     solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     543
#     544     if t_eval is None:
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in __init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      87                  first_step=None, **extraneous):
#      88         warn_extraneous(extraneous)
# ---> 89         super(RungeKutta, self).__init__(fun, t0, y0, t_bound, vectorized,
#      90                                          support_complex=True)
#      91         self.y_old = None
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in __init__(self, fun, t0, y0, t_bound, vectorized, support_complex)
#     117         self.t_old = None
#     118         self.t = t0
# --> 119         self._fun, self.y = check_arguments(fun, y0, support_complex)
#     120         self.t_bound = t_bound
#     121         self.vectorized = vectorized
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in check_arguments(fun, y0, support_complex)
#      15
#      16     if y0.ndim != 1:
# ---> 17         raise ValueError("`y0` must be 1-dimensional.")
#      18
#      19     def fun_wrapped(t, y):
#
# ValueError: `y0` must be 1-dimensional.
