# %% [markdown]
# ## Example data from the wild!!
# Brauer 2008 used microarrays to test the effect of starvation and growth rate on baker’s yeast (S. cerevisiae, a popular model organism for studying molecular genomics because of its simplicity). Basically, if you give yeast plenty of nutrients (a rich media), except that you sharply restrict its supply of one nutrient, you can control the growth rate to whatever level you desire (we do this with a tool called a chemostat). For example, you could limit the yeast’s supply of glucose (sugar, which the cell metabolizes to get energy and carbon), of leucine (an essential amino acid), or of ammonium (a source of nitrogen).
#
# “Starving” the yeast of these nutrients lets us find genes that:
#
# Raise or lower their activity in response to growth rate. Growth-rate dependent expression patterns can tell us a lot about cell cycle control, and how the cell responds to stress.
# Respond differently when different nutrients are being limited. These genes may be involved in the transport or metabolism of those nutrients.
# Sounds pretty cool, right? So let’s get started!
#
# You can check out the paper here: https://www.molbiolcell.org/doi/full/10.1091/mbc.e07-08-0779

# %% [markdown]
# ### 1. Start by loading in the data as a pandas dataframe
# - data file = bcmb_bootcamp2020/day3/data/Brauer2008_DataSet1_clean.tds
# - Note this is a tab separated file, you will need to specify the delimeter as "\t" in your load command

# %%
import pandas as pd

# %%
data_origin=pd.read_csv('/Users/timp/bcmb_bootcamp/day3/data/Brauer2008_DataSet1_clean.tds', sep='\t')

# %%
x=pd.read_table('/Users/timp/bcmb_bootcamp/day3/data/Brauer2008_DataSet1_clean.tds')

# %% [markdown]
# Each of those columns like G0.05, N0.3 and so on represents gene expression values for that sample, as measured by the microarray. The column titles show the condition: G0.05, for instance, means the limiting nutrient was glucose and the growth rate was .05. A higher value means the gene was more expressed in that sample, lower means the gene was less expressed. In total the yeast was grown with six limiting nutrients and six growth rates, which makes 36 samples, and therefore 36 columns, of gene expression data.

# %%
data_origin
# Out:
#             GID        YORF  \
# 0     GENE1331X  A_06_P5820
# 1     GENE4924X  A_06_P5866
# 2     GENE4690X  A_06_P1834
# 3     GENE1177X  A_06_P4928
# 4      GENE511X  A_06_P5620
# ...         ...         ...
# 5532  GENE2833X  A_06_P6094
# 5533   GENE271X  A_06_P3243
# 5534  GENE1691X  A_06_P4196
# 5535  GENE1755X  A_06_P4680
# 5536  GENE4255X  A_06_P6304
#
#                                                    NAME  GWEIGHT  G0.05  G0.1  \
# 0     SFB2       -- ER to Golgi transport -- molecul...        1  -0.24 -0.13
# 1               -- biological process unknown -- mol...        1   0.28  0.13
# 2     QRI7       -- proteolysis and peptidolysis -- ...        1  -0.02 -0.27
# 3     CFT2       -- mRNA polyadenylylation* -- RNA b...        1  -0.33 -0.41
# 4     SSO2       -- vesicle fusion* -- t-SNARE activ...        1   0.05  0.02
# ...                                                 ...      ...    ...   ...
# 5532  KRE1       -- cell wall organization and bioge...        1   0.41 -0.28
# 5533  MTL1       -- cell wall organization and bioge...        1   0.50 -0.12
# 5534  KRE9       -- cell wall organization and bioge...        1   0.15  0.09
# 5535  UTH1       -- mitochondrion organization and b...        1   0.63  0.38
# 5536            -- biological process unknown -- mol...        1   0.18  0.05
#
#       G0.15  G0.2  G0.25  G0.3  ...  L0.15  L0.2  L0.25  L0.3  U0.05  U0.1  \
# 0     -0.21 -0.15  -0.05 -0.05  ...   0.13  0.20   0.17  0.11  -0.06 -0.26
# 1     -0.40 -0.48  -0.11  0.17  ...   0.02  0.04   0.03  0.01  -1.02 -0.91
# 2     -0.27 -0.02   0.24  0.25  ...  -0.07 -0.05  -0.13 -0.04  -0.91 -0.94
# 3     -0.24 -0.03  -0.03  0.00  ...  -0.05  0.02   0.00  0.08  -0.53 -0.51
# 4      0.40  0.34  -0.13 -0.14  ...   0.00 -0.11   0.04  0.01  -0.45 -0.09
# ...     ...   ...    ...   ...  ...    ...   ...    ...   ...    ...   ...
# 5532   0.30  0.50  -0.05 -0.08  ...   0.38  0.23   0.21  0.15   0.32  0.62
# 5533   0.25  0.24   0.13  0.02  ...   0.25 -0.02  -0.06 -0.10    NaN  0.50
# 5534   0.21  0.46   0.19 -0.02  ...   0.37  0.21   0.16 -0.01  -0.68  0.63
# 5535   0.05  0.12   0.13 -0.01  ...  -0.07  0.02   0.24  0.18  -0.89  0.19
# 5536   0.11  0.09  -0.02  0.03  ...  -0.07 -0.08  -0.02 -0.06   0.03  0.14
#
#       U0.15  U0.2  U0.25  U0.3
# 0     -0.05 -0.28  -0.19  0.09
# 1     -0.59 -0.61  -0.17  0.18
# 2     -0.42 -0.36  -0.49 -0.47
# 3     -0.26  0.05  -0.14 -0.01
# 4     -0.13  0.02  -0.09 -0.03
# ...     ...   ...    ...   ...
# 5532   0.54  0.01   0.56  0.28
# 5533   0.29 -0.14   0.47  0.27
# 5534   0.41  0.09   0.48  0.43
# 5535   0.03  0.04   0.13  0.19
# 5536   0.00 -0.21   0.07  0.04
#
# [5537 rows x 40 columns]

# %% [markdown]
# Now that you have loaded in and looked at the data list 2 reasons why this dataset does NOT follow the rules of tidy data (hint review section 2.3 of Hadly Wickam's Tidy data paper http://vita.had.co.nz/papers/tidy-data.pdf)

# %% [markdown]
# ANSWER:
# 1.
# 2.

# %% [markdown]
# ### 2. Make a new dataframe called df_clean that follows the tidy data rules, have it print
# - (hint "NAME" column consists of gene name, biological functions, molecular functions, systematic names, and gene number. Split into 5 separate columns with unique names. This might be helpful https://pandas.pydata.org/pandas-docs/version/0.23.1/generated/pandas.Series.str.split.html)

# %%
df_clean=x.drop(columns=['GID','YORF', 'GWEIGHT'])

# %%
df_clean=df_clean.melt(id_vars='NAME')
df_clean
# Out:
#                                                      NAME variable  value
# 0       SFB2       -- ER to Golgi transport -- molecul...    G0.05  -0.24
# 1                 -- biological process unknown -- mol...    G0.05   0.28
# 2       QRI7       -- proteolysis and peptidolysis -- ...    G0.05  -0.02
# 3       CFT2       -- mRNA polyadenylylation* -- RNA b...    G0.05  -0.33
# 4       SSO2       -- vesicle fusion* -- t-SNARE activ...    G0.05   0.05
# ...                                                   ...      ...    ...
# 199327  KRE1       -- cell wall organization and bioge...     U0.3   0.28
# 199328  MTL1       -- cell wall organization and bioge...     U0.3   0.27
# 199329  KRE9       -- cell wall organization and bioge...     U0.3   0.43
# 199330  UTH1       -- mitochondrion organization and b...     U0.3   0.19
# 199331            -- biological process unknown -- mol...     U0.3   0.04
#
# [199332 rows x 3 columns]

# %%
df_clean['NAME'].str.split(' -- ', expand=True)
# Out:
#                  0                                           1  \
# 0       SFB2                             ER to Golgi transport
# 1                                   biological process unknown
# 2       QRI7                      proteolysis and peptidolysis
# 3       CFT2                           mRNA polyadenylylation*
# 4       SSO2                                   vesicle fusion*
# ...            ...                                         ...
# 199327  KRE1             cell wall organization and biogenesis
# 199328  MTL1             cell wall organization and biogenesis
# 199329  KRE9            cell wall organization and biogenesis*
# 199330  UTH1        mitochondrion organization and biogenesis*
# 199331                              biological process unknown
#
#                                           2        3        4
# 0                molecular function unknown  YNL049C  1082129
# 1                molecular function unknown  YNL095C  1086222
# 2             metalloendopeptidase activity  YDL104C  1085955
# 3                               RNA binding  YLR115W  1081958
# 4                          t-SNARE activity  YMR183C  1081214
# ...                                     ...      ...      ...
# 199327  structural constituent of cell wall  YNL322C  1083836
# 199328           molecular function unknown  YGR023W  1080930
# 199329           molecular function unknown  YJL174W  1082539
# 199330           molecular function unknown  YKR042W  1082610
# 199331           molecular function unknown  YOL111C  1085465
#
# [199332 rows x 5 columns]

# %%
df_clean[['genename', 'biofunction', 'molfunction', 'sysname', 'genenum']]=df_clean['NAME'].str.split(' -- ', expand=True)

# %%
df_clean
# Out:
#                                                      NAME variable  value  \
# 0       SFB2       -- ER to Golgi transport -- molecul...    G0.05  -0.24
# 1                 -- biological process unknown -- mol...    G0.05   0.28
# 2       QRI7       -- proteolysis and peptidolysis -- ...    G0.05  -0.02
# 3       CFT2       -- mRNA polyadenylylation* -- RNA b...    G0.05  -0.33
# 4       SSO2       -- vesicle fusion* -- t-SNARE activ...    G0.05   0.05
# ...                                                   ...      ...    ...
# 199327  KRE1       -- cell wall organization and bioge...     U0.3   0.28
# 199328  MTL1       -- cell wall organization and bioge...     U0.3   0.27
# 199329  KRE9       -- cell wall organization and bioge...     U0.3   0.43
# 199330  UTH1       -- mitochondrion organization and b...     U0.3   0.19
# 199331            -- biological process unknown -- mol...     U0.3   0.04
#
#           genename                                 biofunction  \
# 0       SFB2                             ER to Golgi transport
# 1                                   biological process unknown
# 2       QRI7                      proteolysis and peptidolysis
# 3       CFT2                           mRNA polyadenylylation*
# 4       SSO2                                   vesicle fusion*
# ...            ...                                         ...
# 199327  KRE1             cell wall organization and biogenesis
# 199328  MTL1             cell wall organization and biogenesis
# 199329  KRE9            cell wall organization and biogenesis*
# 199330  UTH1        mitochondrion organization and biogenesis*
# 199331                              biological process unknown
#
#                                 molfunction  sysname  genenum
# 0                molecular function unknown  YNL049C  1082129
# 1                molecular function unknown  YNL095C  1086222
# 2             metalloendopeptidase activity  YDL104C  1085955
# 3                               RNA binding  YLR115W  1081958
# 4                          t-SNARE activity  YMR183C  1081214
# ...                                     ...      ...      ...
# 199327  structural constituent of cell wall  YNL322C  1083836
# 199328           molecular function unknown  YGR023W  1080930
# 199329           molecular function unknown  YJL174W  1082539
# 199330           molecular function unknown  YKR042W  1082610
# 199331           molecular function unknown  YOL111C  1085465
#
# [199332 rows x 8 columns]

# %% [markdown]
# ### 3. Subsetting!
#
# Next let's dig into the data more. Using pandas again subset the dataframe to just keep the genes that have the string "cell cycle" as their biological process. (see note about "NAME" column above in step 2)

# %%
df_clean['biofunction'].unique()
# Out:
# array(['ER to Golgi transport', 'biological process unknown',
#        'proteolysis and peptidolysis', 'mRNA polyadenylylation*',
#        'vesicle fusion*', 'riboflavin biosynthesis',
#        'vacuolar acidification', 'deadenylylation-independent decapping',
#        'protein retention in Golgi*',
#        'negative regulation of exit from mitosis*',
#        'cytokinesis, completion of separation',
#        'cell wall organization and biogenesis*',
#        'cytochrome c oxidase complex assembly*',
#        'pantothenate biosynthesis*',
#        'transcription from mitochondrial promoter',
#        'invasive growth (sensu Saccharomyces)*',
#        'positive regulation of transcription from RNA polymerase II promoter',
#        'cation homeostasis', 'nuclear mRNA splicing, via spliceosome*',
#        'regulation of glycogen biosynthesis*', 'RNA splicing*',
#        'mitochondrial genome maintenance*', 'sulfate transport',
#        'telomerase-independent telomere maintenance*', '',
#        'response to unfolded protein*',
#        'intracellular protein transport*', 'response to drug*',
#        'choline transport', 'chromatin remodeling',
#        'cell wall organization and biogenesis',
#        'negative regulation of transcription from RNA polymerase II promoter',
#        'S-methylmethionine transport', 'sulfur amino acid metabolism',
#        'phosphate metabolism', 'peroxisome organization and biogenesis*',
#        'fatty acid elongation, unsaturated fatty acid', 'transport*',
#        'telomere maintenance*', 'pseudohyphal growth*',
#        'chromatin silencing at telomere*', 'cytokinesis',
#        'cell wall mannoprotein biosynthesis*', 'cytokinesis*',
#        'adaptation to pheromone during conjugation with cellular fusion',
#        'phospholipid biosynthesis', 'mRNA-nucleus export*',
#        'secretory pathway', 'pantothenate biosynthesis',
#        "'de novo' IMP biosynthesis*", 'ubiquinone biosynthesis',
#        'biological process unknown*',
#        'phenylalanine biosynthesis, prephenate pathway', 'transcription*',
#        'protein biosynthesis*', 'protein biosynthesis',
#        'aerobic respiration*', 'RNA splicing', 'GPI anchor biosynthesis',
#        'nuclear mRNA splicing, via spliceosome',
#        'mitochondrion organization and biogenesis*',
#        'chromatin remodeling*', 'endocytosis',
#        'regulation of progression through cell cycle',
#        'snoRNA metabolism', 'DNA replication initiation*',
#        'nucleosome assembly', 'triacylglycerol biosynthesis*',
#        'myo-inositol transport',
#        'actin cytoskeleton organization and biogenesis',
#        'protein amino acid N-linked glycosylation',
#        'G1/S transition of mitotic cell cycle*',
#        'protein amino acid phosphorylation*',
#        'ER-associated protein catabolism',
#        'response to oxidative stress*',
#        '35S primary transcript processing*', 'karyogamy',
#        'cellular morphogenesis during vegetative growth',
#        'sterol transport', 'vacuolar acidification*',
#        'phosphatidylcholine metabolism', 'chromosome segregation',
#        'bud site selection*', 'protein amino acid O-linked glycosylation',
#        'transport', 'protein-nucleus import', 'translational elongation',
#        'ubiquinone metabolism', 'phosphatidylcholine biosynthesis',
#        'nuclear migration, microtubule-mediated',
#        'sporulation (sensu Fungi)', 'bud site selection',
#        'vesicle-mediated transport',
#        'transcription from RNA polymerase II promoter',
#        'ammonium transport', 'endocytosis*',
#        'protein amino acid N-linked glycosylation*', 'AMP biosynthesis*',
#        'actin cytoskeleton organization and biogenesis*',
#        'tRNA-nucleus export*', 'biotin biosynthesis',
#        'mitochondrial inner membrane protein import',
#        'mRNA catabolism, nonsense-mediated decay',
#        'translational initiation',
#        'peptidyl-diphthamide biosynthesis from peptidyl-histidine',
#        'asparagine biosynthesis', 'response to stress*',
#        'asparaginyl-tRNA aminoacylation', 'rRNA-nucleus export*',
#        'protein complex assembly*',
#        'regulation of transcription from RNA polymerase II promoter*',
#        'lipid metabolism*', 'fatty acid biosynthesis',
#        'lysine biosynthesis via aminoadipic acid',
#        'acetyl-CoA biosynthesis from pyruvate', 'protein folding*',
#        'proteolysis and peptidolysis*', 'NAD metabolism',
#        'mitochondrial intermembrane space protein import*',
#        'copper ion import', 'N-terminal peptidyl-methionine acetylation',
#        'Group I intron splicing*', 'mitochondrial protein processing',
#        'RNA catabolism', 'nucleotide metabolism',
#        'protein deubiquitination', 'aldehyde metabolism',
#        'glucose metabolism*', 'histone acetylation',
#        'glycine catabolism*', 'mitochondrion organization and biogenesis',
#        'maltose catabolism', 'mitochondrial genome maintenance',
#        'thiamin biosynthesis*', 'tricarboxylic acid cycle*',
#        'electron transport', 'phosphate transport',
#        'ATP synthesis coupled proton transport',
#        'regulation of transcription, DNA-dependent*', 'hexose transport',
#        'glycogen biosynthesis', 'NAD catabolism',
#        'signal transduction during conjugation with cellular fusion',
#        'mitochondrial transport',
#        'mitochondrial electron transport, NADH to ubiquinone',
#        'mitochondrial electron transport, ubiquinol to cytochrome c*',
#        'ribosome biogenesis', 'mitochondrial matrix protein import',
#        'synaptonemal complex formation*', 'protein targeting*',
#        'methionyl-tRNA aminoacylation', 'butanediol fermentation',
#        'aerobic respiration', 'ribosome biogenesis*',
#        'pyruvate metabolism', 'methionine metabolism*',
#        'rRNA processing*', 'ER to Golgi transport*', 'sulfur metabolism',
#        'lysyl-tRNA aminoacylation', 'phospholipid biosynthesis*',
#        'aldehyde metabolism*', 'RNA metabolism', 'purine base metabolism',
#        'pentose-phosphate shunt', 'methionine metabolism',
#        'translational elongation*', 'nucleocytoplasmic transport',
#        'peptide pheromone maturation', 'heme biosynthesis',
#        'nucleobase, nucleoside, nucleotide and nucleic acid metabolism*',
#        'sphingolipid biosynthesis',
#        'protein amino acid dephosphorylation*',
#        'regulation of cell redox homeostasis',
#        'one-carbon compound metabolism',
#        'regulation of exit from mitosis*',
#        'protein amino acid acetylation', 'tRNA modification',
#        'cysteine metabolism*', 'sporulation (sensu Fungi)*',
#        'telomerase-dependent telomere maintenance*',
#        'microtubule cytoskeleton organization and biogenesis',
#        '35S primary transcript processing',
#        'glycerophospholipid metabolism', 'glycerol transport*',
#        'protein amino acid glycosylation*', 'sphingolipid biosynthesis*',
#        'protein-ER targeting*', 'tyrosyl-tRNA aminoacylation',
#        'sucrose catabolism', 'heme a biosynthesis',
#        'protein complex assembly', 'mitochondrial matrix protein import*',
#        'threonyl-tRNA aminoacylation',
#        'cytoskeleton organization and biogenesis', 'rRNA modification',
#        'cytochrome c oxidase complex assembly', 'manganese ion transport',
#        'tRNA modification*', 'basic amino acid transport',
#        'aromatic amino acid family biosynthesis',
#        'Group I intron splicing',
#        'inner mitochondrial membrane organization and biogenesis',
#        'chromosome organization and biogenesis (sensu Eukaryota)',
#        'osmosensory signaling pathway', 'GTP biosynthesis',
#        'NAD biosynthesis', 'replicative cell aging*',
#        'G2/M transition of mitotic cell cycle*',
#        'phenylalanyl-tRNA aminoacylation', 'ribosome-nucleus export',
#        'mitotic sister chromatid segregation*',
#        'negative regulation of transcription from RNA polymerase II promoter*',
#        'transcription from RNA polymerase III promoter',
#        'DNA replication',
#        'mRNA catabolism, deadenylylation-dependent decay*',
#        'regulation of progression through cell cycle*',
#        'mRNA-nucleus export', 'cytochrome c-heme linkage',
#        'vesicle-mediated transport*', 'phosphatidylcholine biosynthesis*',
#        'branched chain family amino acid biosynthesis',
#        'peroxisome organization and biogenesis',
#        'regulation of transcription, DNA-dependent',
#        'tryptophan biosynthesis', 'arginine biosynthesis*',
#        'leucine biosynthesis', 'histidine biosynthesis', 'RNA processing',
#        'signal transduction*', 'uracil transport',
#        'purine nucleotide biosynthesis',
#        'intracellular copper ion transport', 'sterol metabolism',
#        'ergosterol biosynthesis', 'protein folding',
#        'sodium ion homeostasis', 'plasmid maintenance',
#        'establishment of cell polarity (sensu Fungi)*',
#        'regulation of transcription', 'thiamin biosynthesis',
#        'positive regulation of transcription from RNA polymerase II promoter*',
#        'poly(A)+ mRNA-nucleus export', 'gluconeogenesis*', 'DNA repair',
#        'one-carbon compound metabolism*', 'DNA repair*',
#        'nucleotide-excision repair*', 'response to stress',
#        'nascent polypeptide association',
#        'transcription initiation from RNA polymerase II promoter',
#        'nucleotide metabolism*', 'protein monoubiquitination',
#        'low-affinity zinc ion transport', 'zinc ion transport',
#        'methionine biosynthesis',
#        'regulation of transcription from RNA polymerase II promoter',
#        'glutamate biosynthesis*', 'fermentation', 'tRNA methylation',
#        'ribosomal large subunit assembly and maintenance',
#        'N-terminal peptidyl-glycine N-myristoylation',
#        'transcription from RNA polymerase I promoter',
#        'GPI anchor biosynthesis*', 'folic acid and derivative metabolism',
#        'posttranslational protein-membrane targeting',
#        'histidyl-tRNA aminoacylation', 'exocytosis*', 'glycolysis*',
#        'attachment of GPI anchor to protein',
#        'mitotic sister chromatid cohesion', 'microtubule nucleation*',
#        'negative regulation of DNA transposition',
#        'ribosomal large subunit-nucleus export',
#        'G1/S-specific transcription in mitotic cell cycle',
#        'nucleocytoplasmic transport*', 'rRNA modification*',
#        'calcium ion transport', 'regulation of transcription*',
#        'metabolism', 'fatty acid metabolism',
#        'ER organization and biogenesis', 'viral life cycle',
#        'pre-replicative complex formation and maintenance',
#        'processing of 20S pre-rRNA*', 'mating type switching*',
#        'cell cycle', 'response to osmotic stress*', 'rRNA processing',
#        'ribosomal large subunit biogenesis',
#        'purine nucleotide biosynthesis*', 'protein-vacuolar targeting',
#        'multidrug transport', 'alcohol metabolism',
#        'intracellular protein transport', 'tRNA processing',
#        'small GTPase mediated signal transduction',
#        'pyrimidine deoxyribonucleoside triphosphate catabolism',
#        'cellular morphogenesis', 'translational initiation*',
#        'processing of 20S pre-rRNA',
#        'regulation of transcription, mating-type specific',
#        'ribosome assembly*',
#        'posttranslational protein-membrane targeting*',
#        'seryl-tRNA aminoacylation', 'sphingolipid metabolism',
#        'ribosomal large subunit assembly and maintenance*',
#        'protein retention in ER', 'U2-type spliceosome dissembly',
#        'ribosomal large subunit biogenesis*',
#        'protein amino acid glycosylation',
#        "removal of tRNA 3'-trailer sequence",
#        'peptidyl-diphthamide biosynthesis from peptidyl-histidine*',
#        'hypusine biosynthesis from peptidyl-lysine',
#        'mitochondrial citrate transport',
#        'protein amino acid dephosphorylation',
#        'transcription from RNA polymerase I promoter*',
#        'intracellular mRNA localization', 'response to unfolded protein',
#        'phosphatidylethanolamine biosynthesis',
#        'phosphatidylglycerol biosynthesis*',
#        'very-long-chain fatty acid metabolism', 'zinc ion homeostasis*',
#        'tryptophanyl-tRNA aminoacylation', 'asparagine catabolism',
#        'mitochondrial magnesium ion transport*', 'intra-Golgi transport*',
#        'proline biosynthesis', 'UDP-galactose transport',
#        'manganese ion transport*', 'FAD transport', 'DNA recombination*',
#        'protein modification', 'iron ion transport',
#        'protein-lipoylation', 'meiotic recombination',
#        'cotranslational protein-membrane targeting',
#        'G1/S transition of mitotic cell cycle', 'copper ion homeostasis*',
#        'nicotinamide mononucleotide transport',
#        'valyl-tRNA aminoacylation', 'loss of chromatin silencing',
#        'glucose 1-phosphate utilization*', 'chromosome segregation*',
#        'regulation of translational initiation*', 'GMP metabolism',
#        'deadenylylation-dependent decapping*',
#        'protein-membrane targeting*',
#        'regulation of cyclin dependent protein kinase activity*',
#        'mRNA processing*', 'cell wall biosynthesis (sensu Fungi)',
#        'tRNA splicing', 'mismatch repair*', 'meiotic recombination*',
#        'sulfate assimilation*', 'protein-nucleus export',
#        'transcription from RNA polymerase II promoter*',
#        'mRNA catabolism, deadenylylation-dependent decay',
#        'DNA metabolism', 'filamentous growth*',
#        'intracellular mRNA localization*',
#        'serine family amino acid biosynthesis',
#        'SRP-dependent cotranslational protein-membrane targeting, translocation',
#        'translation*', 'processing of 27S pre-rRNA*', 'cell growth',
#        'axial bud site selection', 'pyrimidine nucleotide metabolism',
#        'actin filament organization*', 'ceramide biosynthesis',
#        'intron homing', 'anaerobic respiration',
#        'protein-nucleus import*', 'pseudohyphal growth',
#        'pyrimidine salvage', 'DNA-dependent DNA replication',
#        'L-arginine transport*', 'late endosome to vacuole transport',
#        'carbon utilization', 'meiosis', 'meiosis*', 'mRNA metabolism',
#        'FMN biosynthesis',
#        'outer mitochondrial membrane organization and biogenesis',
#        'iron ion homeostasis*', 'peptidyl-arginine methylation',
#        'chromatin silencing at telomere', 'acetate metabolism',
#        'amino acid transport', 'aromatic amino acid transport',
#        'ergosterol biosynthesis*', 'Golgi to vacuole transport',
#        'regulation of translational initiation', 'response to drug',
#        'protein amino acid biotinylation',
#        'mitotic sister chromatid cohesion*', 'mRNA polyadenylylation',
#        'microtubule nucleation',
#        'regulation of progression through mitotic cell cycle',
#        'histone methylation*', 'MAPKKK cascade',
#        'mitotic spindle checkpoint',
#        'nucleobase, nucleoside, nucleotide and nucleic acid metabolism',
#        'protein amino acid geranylgeranylation', 'tRNA processing*',
#        'tRNA aminoacylation for protein translation',
#        'ubiquitin-dependent protein catabolism',
#        'ubiquitin-dependent protein catabolism*',
#        'response to dessication', 'bipolar bud site selection*',
#        'DNA damage response, signal transduction resulting in induction of apoptosis',
#        'steroid metabolism', 'glycerol metabolism',
#        'transcription from RNA polymerase III promoter*',
#        'conjugation with cellular fusion*',
#        "'de novo' pyrimidine base biosynthesis*", 'polyamine transport',
#        'arginine catabolism to ornithine', 'biotin transport',
#        'lagging strand elongation', 'transcription',
#        'electron transport*', 'pyridoxine metabolism*',
#        'histidine biosynthesis*', 'arginine biosynthesis',
#        'branched chain family amino acid biosynthesis*',
#        'sulfite transport', 'ER-associated protein catabolism*',
#        'leucyl-tRNA aminoacylation', 'iron ion homeostasis',
#        'dicarboxylic acid transport', 'sulfate transport*',
#        'protein-mitochondrial targeting*', 'nucleoside catabolism',
#        'protein monoubiquitination*', 'ribosome assembly',
#        'protein-vacuolar targeting*', 'histone deacetylation*',
#        'pyruvate metabolism*', 'intracellular sequestering of iron ion',
#        'nucleotide-sugar transport', 'mRNA catabolism*',
#        'vacuolar transport', 'high affinity iron ion transport*',
#        'ferric-enterobactin transport',
#        'high affinity iron ion transport', 'siderophore transport',
#        'flocculation (sensu Saccharomyces)', 'iron ion transport*',
#        'iron-siderophore transport', 'high-affinity zinc ion transport',
#        'lysine biosynthesis', 'intracellular copper ion transport*',
#        'coenzyme A biosynthesis', 'protein-peroxisome targeting*',
#        'response to arsenic', 'regulation of nitrogen utilization*',
#        'ATP synthesis coupled proton transport*', 'bile acid transport',
#        'vacuole fusion, non-autophagic*', 'protein neddylation*',
#        'histone acetylation*', 'ubiquinone metabolism*',
#        'copper ion transport', 'alpha-glucoside transport*',
#        'protein deubiquitination*', 'budding cell bud growth*',
#        'post-chaperonin tubulin folding pathway*', 'spliceosome assembly',
#        'chromatin silencing at silent mating-type cassette',
#        'transcription, DNA-dependent', 'microtubule-based process',
#        'protein sumoylation', 'sphingolipid metabolism*',
#        'N-terminal protein amino acid acetylation',
#        'cAMP-mediated signaling', 'ion transport',
#        'RNA elongation from RNA polymerase II promoter*',
#        'terpenoid biosynthesis', 'cation transport',
#        'cell wall chitin biosynthesis*', 'NADH metabolism',
#        'response to oxidative stress', 'purine base biosynthesis*',
#        'tyrosine metabolism', 'telomere capping', 'glycerol transport',
#        'aspartate biosynthesis*',
#        'mitotic spindle organization and biogenesis in nucleus*',
#        'ceramide biosynthesis*', 'regulation of pH*',
#        'regulation of translational elongation', 'response to radiation',
#        'phospholipid metabolism', 'glutamate biosynthesis',
#        'nitrogen compound metabolism*', 'regulation of meiosis',
#        'acetate biosynthesis', 'uridine transport',
#        'premeiotic DNA synthesis', 'synaptonemal complex formation',
#        'purine transport*', 'nitrogen compound metabolism',
#        'sulfur metabolism*', 'Golgi to endosome transport',
#        'meiotic DNA recombinase assembly*',
#        'agglutination during conjugation with cellular fusion',
#        'pyrimidine base metabolism', 'protein processing*',
#        'maintenance of cell polarity (sensu Fungi)',
#        'response to osmotic stress', 'alanyl-tRNA aminoacylation',
#        'adenine catabolism', 'protein-ER targeting',
#        'fatty acid elongation', 'glutathione metabolism',
#        'dolichol-linked oligosaccharide biosynthesis',
#        'G1-specific transcription in mitotic cell cycle',
#        'chromatin assembly or disassembly', 'rRNA transcription',
#        'Ras protein signal transduction*',
#        'fructose 2,6-bisphosphate metabolism*',
#        'double-strand break repair*',
#        'oligosaccharide-lipid intermediate assembly',
#        'postreplication repair*', 'chitin biosynthesis*',
#        'budding cell bud growth', 'lipid transport*', 'cell cycle*',
#        'vacuole inheritance', 'glycyl-tRNA aminoacylation*',
#        'DNA-dependent DNA replication*',
#        'transcription initiation from RNA polymerase II promoter*',
#        'cell ion homeostasis',
#        'SRP-dependent cotranslational protein-membrane targeting, translocation*',
#        'response to pheromone', 'response to metal ion*',
#        'thiamin transport', 'exocytosis', 'glycolysis',
#        'galactose metabolism', 'processing of 27S pre-rRNA',
#        'chromatin silencing at ribosomal DNA*',
#        'spore wall assembly (sensu Fungi)', 'Golgi vesicle transport',
#        'protein deneddylation*', 'tubulin folding', 'DNA recombination',
#        'spindle pole body duplication in nuclear envelope*',
#        'error-free DNA repair', 'mRNA processing',
#        'intra-Golgi transport', 'protein catabolism',
#        'signal transduction during conjugation with cellular fusion*',
#        'mitosis', 'cytidine catabolism*', 'osmoregulation',
#        'charged-tRNA modification', 'sterol biosynthesis',
#        'response to pheromone during conjugation with cellular fusion*',
#        'rRNA metabolism', 'amino acid metabolism',
#        'regulation of DNA replication', 'signal peptide processing',
#        'mitochondrion inheritance*', 'peptide pheromone export',
#        'beta-tubulin folding*', 'regulation of signal transduction',
#        'transcription initiation from RNA polymerase III promoter',
#        'microtubule-based process*', 'thiamin diphosphate biosynthesis',
#        'retrograde transport, Golgi to ER',
#        'intracellular signaling cascade',
#        'conjugation with cellular fusion', 'protein catabolism*',
#        'vesicle organization and biogenesis',
#        'inositol phosphate dephosphorylation', 'pyrimidine salvage*',
#        'glutaminyl-tRNA aminoacylation', 'DNA replication*',
#        'protein secretion', 'ubiquitin cycle',
#        'monovalent inorganic cation transport',
#        'retrograde transport, Golgi to ER*', 'response to toxin',
#        'folic acid and derivative biosynthesis',
#        'response to cadmium ion*', 'protein amino acid farnesylation',
#        'double-strand break repair via nonhomologous end-joining*',
#        'cellular respiration', 'tRNA splicing*',
#        'G2/M-specific transcription in mitotic cell cycle',
#        'regulation of termination of mating projection growth*',
#        'steroid biosynthesis', 'vacuole inheritance*',
#        'mitochondrial electron transport, cytochrome c to oxygen*',
#        'mismatch repair', 'polyphosphate metabolism',
#        'phosphate metabolism*', 'glycerophosphodiester transport',
#        'magnesium ion transport*', 'vacuole fusion, non-autophagic',
#        'diadenosine polyphosphate metabolism',
#        'protein amino acid O-linked glycosylation*',
#        'late endosome to vacuole transport*',
#        'negative regulation of transcription from RNA polymerase III promoter',
#        'cell surface receptor linked signal transduction',
#        'beta-1,6 glucan biosynthesis',
#        'monovalent inorganic cation homeostasis', 'chromatin silencing',
#        'membrane organization and biogenesis',
#        'mitotic sister chromatid segregation',
#        'telomerase-dependent telomere maintenance',
#        'potassium ion homeostasis',
#        'nuclear pore organization and biogenesis', 'sporulation*',
#        'RNA elongation from RNA polymerase II promoter',
#        'cell wall mannoprotein biosynthesis', 'DNA dealkylation',
#        'phosphatidylserine catabolism*', 'lipid metabolism',
#        'L-aspartate transport*', 'DNA topological change',
#        'regulation of cell size', 'vacuolar protein catabolism',
#        'Golgi to vacuole transport*', 'histone deacetylation',
#        'protein-membrane targeting', 'response to chemical substance',
#        'water transport', 'signal transduction', 'phospholipid transport',
#        'manganese ion homeostasis', 'negative regulation of translation',
#        'mitochondrial intermembrane space protein import',
#        'cellular morphogenesis*', 'zinc ion homeostasis',
#        'cysteine biosynthesis', 'methionine salvage',
#        'sulfur amino acid transport', 'methionine biosynthesis*',
#        'sulfate assimilation', 'sulfur amino acid metabolism*',
#        'response to heat*', 'propionate metabolism*',
#        'fatty acid beta-oxidation', 'fatty acid transport',
#        'snoRNA metabolism*', 'lysine biosynthesis via aminoadipic acid*',
#        'FAD biosynthesis', 'mitochondrial fission',
#        'protein-cofactor linkage', 'fatty acid metabolism*',
#        'regulation of DNA replication initiation',
#        'iron-sulfur cluster assembly',
#        'Golgi to plasma membrane transport*', 'vitamin transport',
#        'purine nucleoside catabolism', 'double-strand break repair',
#        'aromatic compound catabolism', 'removal of nonhomologous ends*',
#        'drug transport*', 'L-cystine transport',
#        'intracellular signaling cascade*',
#        'phosphatidic acid biosynthesis',
#        'mitochondrial magnesium ion transport', 'DNA damage checkpoint*',
#        'cell cycle arrest in response to pheromone',
#        'peptidyl-glutamine methylation', 'peroxisome inheritance',
#        'karyogamy during conjugation with cellular fusion',
#        'mRNA capping', 'sporulation',
#        'adaptation to pheromone during conjugation with cellular fusion*',
#        'chromatin modification',
#        'establishment and/or maintenance of chromatin architecture',
#        'actin cortical patch assembly',
#        'transcription termination from Pol II promoter, RNA polymerase(A) coupled*',
#        'attachment of spindle microtubules to kinetochore',
#        'chromatin assembly or disassembly*', 'protein-nucleus export*',
#        'misfolded or incompletely synthesized protein catabolism*',
#        'tryptophan biosynthesis*', 'vesicle fusion',
#        'barbed-end actin filament capping', 'protein localization',
#        'histone methylation', 'sensory perception of chemical stimulus',
#        'meiotic chromosome segregation*',
#        'negative regulation of gluconeogenesis', 'protein sumoylation*',
#        'lactate metabolism', 'microautophagy',
#        'vacuole organization and biogenesis*',
#        'UDP-N-acetylglucosamine biosynthesis',
#        'S-adenosylmethionine transport',
#        'cellular morphogenesis during conjugation with cellular fusion*',
#        'Ras protein signal transduction', 'carbohydrate metabolism*',
#        'nucleotide-excision repair, DNA damage recognition',
#        'movement of group I intron', 'spore wall assembly (sensu Fungi)*',
#        'lipoic acid biosynthesis', 'monosaccharide metabolism',
#        'aromatic amino acid family metabolism',
#        'regulation of translational termination',
#        'intracellular accumulation of glycerol',
#        'regulation of cyclin dependent protein kinase activity',
#        'purine nucleotide metabolism', 'mitotic spindle checkpoint*',
#        'protein ubiquitination*', 'regulation of phosphate metabolism',
#        'double-strand break repair via nonhomologous end-joining',
#        'nuclear migration',
#        'positive regulation of transcription from RNA polymerase II promoter by pheromones',
#        'U2-type catalytic spliceosome formation for first transesterification step',
#        'mitochondrion inheritance',
#        'U2-type nuclear mRNA branch site recognition',
#        'cis assembly of U2-type pre-catalytic spliceosome',
#        'secretory pathway*', 'Rho protein signal transduction',
#        'protein thiol-disulfide exchange', 'response to metal ion',
#        'protein processing', 'protein-peroxisome targeting',
#        'DNA strand elongation', 'invasive growth (sensu Saccharomyces)',
#        'spliceosome assembly*',
#        'cellular morphogenesis during conjugation with cellular fusion',
#        'protein deneddylation', 'Golgi to endosome transport*',
#        'Golgi organization and biogenesis',
#        "'de novo' pyrimidine base biosynthesis", 'ethanol metabolism',
#        'actin filament organization', 'base-excision repair*',
#        'small GTPase mediated signal transduction*',
#        'U2-type spliceosome conformational change to release U4 and U1',
#        'myo-inositol metabolism', 'protein modification*',
#        'arabinose catabolism*', 'regulation of translation',
#        'vacuolar protein catabolism*', 'bilirubin transport*',
#        'nitrogen utilization', 'D-ribose metabolism',
#        'cytokinesis, completion of separation*',
#        'regulation of cell growth', 'photoreactive repair',
#        'establishment of mitotic spindle orientation',
#        'regulation of proteolysis and peptidolysis',
#        'glycogen metabolism', 'glucose metabolism', 'autophagy*',
#        'autophagy', 'MAPKKK cascade during cell wall biogenesis',
#        'chromatin silencing at silent mating-type cassette*',
#        'pyridoxine metabolism', 'retrograde transport, endosome to Golgi',
#        'deadenylylation-dependent decapping', 'carbohydrate metabolism',
#        'response to DNA damage stimulus*', 'response to mercury ion',
#        'proton transport', 'regulation of cell redox homeostasis*',
#        'nuclear organization and biogenesis', 'inosine salvage',
#        'microtubule cytoskeleton organization and biogenesis*',
#        'cytokinesis, contractile ring contraction',
#        'protein-mitochondrial targeting', 'glutathione metabolism*',
#        'fatty acid beta-oxidation*', 'ethanol fermentation*',
#        'response to salt stress*', 'glycyl-tRNA aminoacylation',
#        'calcium ion homeostasis*', 'glycogen catabolism',
#        'response to heat', 'protein amino acid phosphorylation',
#        'negative regulation of sporulation', 'replicative cell aging',
#        "nucleotide-excision repair, DNA incision, 3'-to lesion",
#        'response to acid', 'magnesium ion transport',
#        'telomerase-independent telomere maintenance',
#        'cellular response to glucose starvation',
#        'response to xenobiotic stimulus', 'fatty acid biosynthesis*',
#        'regulation of nitrogen utilization',
#        'mitochondrial membrane organization and biogenesis*', 'apoptosis',
#        'regulation of glycogen biosynthesis',
#        'formation of catalytic U2-type spliceosome for second transesterification step',
#        'protein ubiquitination', 'response to copper ion',
#        'osmosensory signaling pathway via two-component system*',
#        'sodium ion transport', 'regulation of exit from mitosis',
#        'neutral amino acid transport', 'allantoin catabolism',
#        'proline catabolism*', 'urea transport', 'not yet annotated',
#        'response to DNA damage stimulus', 'peptide metabolism',
#        'guanine metabolism', 'glutathione catabolism',
#        'arginine metabolism*', 'asparagine catabolism*',
#        'nicotinamide riboside metabolism', 'amino acid transport*',
#        'allantoate transport', 'allantoin transport',
#        'allantoin catabolism*', 'urea transport*', 'ceramide metabolism',
#        'regulation of cell budding', 'formaldehyde catabolism',
#        'sterol biosynthesis*', 'nuclear migration, microtubule-mediated*',
#        'glutamyl-tRNA aminoacylation', 'mRNA splice site selection',
#        'threonine catabolism*',
#        'establishment of mitotic spindle orientation*',
#        'sister chromatid cohesion*', 'glutathione biosynthesis',
#        'protein transport', 'xylulose catabolism',
#        'misfolded or incompletely synthesized protein catabolism',
#        'peroxisome matrix protein import', 'coenzyme A transport',
#        'peptide transport', 'response to antibiotic',
#        'protein neddylation', 'amino acid derivative catabolism',
#        'negative regulation of transcription*',
#        'cell wall chitin biosynthesis', 'oligopeptide transport',
#        'acetyl-CoA biosynthesis', 'carbohydrate transport',
#        'regulation of mitosis',
#        'mitochondrial outer membrane protein import',
#        'response to salt stress', 'nucleoside transport',
#        'positive regulation of transcription',
#        'regulation of amino acid metabolism',
#        'para-aminobenzoic acid metabolism',
#        'peptide pheromone maturation*',
#        'establishment of cell polarity (sensu Fungi)',
#        'arginine catabolism', 'biotin biosynthesis*',
#        'alcohol metabolism*', 'acetyl-CoA biosynthesis*',
#        'carnitine metabolism', 'fermentation*', 'gluconeogenesis',
#        'oxygen and reactive oxygen species metabolism',
#        'glyoxylate cycle', 'fumarate transport*', 'fatty acid oxidation',
#        'propionate metabolism', 'alpha-glucoside transport',
#        'acetate metabolism*', 'lactate transport', 'glycine biosynthesis',
#        'oxidative phosphorylation', 'response to ethanol',
#        'regulation of protein biosynthesis',
#        'transcription termination from Pol II promoter, RNA polymerase(A)-independent',
#        'cell ion homeostasis*', 'protein secretion*',
#        'protein metabolism', 'N-acetylglucosamine biosynthesis',
#        'cytoskeleton organization and biogenesis*',
#        'chromatin silencing*',
#        'G1/S-specific transcription in mitotic cell cycle*',
#        'calcium-mediated signaling',
#        'C-terminal protein amino acid methylation',
#        'G-protein signaling, coupled to cAMP nucleotide second messenger',
#        'meiotic DNA double-strand break formation',
#        'phosphatidylserine biosynthesis'], dtype=object)

# %%
cellcycle=df_clean[df_clean['biofunction']=='cell cycle']

# %%
cycle2=df_clean[df_clean['biofunction'].str.contains('cell cycle')]
cycle2
# Out:
#                                                      NAME variable  value  \
# 108     ZPR1       -- regulation of progression throug...    G0.05   0.00
# 118     PTC2       -- G1/S transition of mitotic cell ...    G0.05  -1.04
# 434     PIN4       -- G2/M transition of mitotic cell ...    G0.05  -0.71
# 445     HSL7       -- regulation of progression throug...    G0.05  -0.56
# 466     SIS2       -- G1/S transition of mitotic cell ...    G0.05   0.16
# ...                                                   ...      ...    ...
# 199116  VHS3       -- G1/S transition of mitotic cell ...     U0.3   0.10
# 199120  SIC1       -- G1/S transition of mitotic cell ...     U0.3   0.02
# 199172  CDC4       -- G1/S transition of mitotic cell ...     U0.3   0.28
# 199191  PTK2       -- G1/S transition of mitotic cell ...     U0.3   0.15
# 199270  POG1       -- G1/S-specific transcription in m...     U0.3  -0.06
#
#           genename                                        biofunction  \
# 108     ZPR1             regulation of progression through cell cycle
# 118     PTC2                   G1/S transition of mitotic cell cycle*
# 434     PIN4                   G2/M transition of mitotic cell cycle*
# 445     HSL7            regulation of progression through cell cycle*
# 466     SIS2                   G1/S transition of mitotic cell cycle*
# ...            ...                                                ...
# 199116  VHS3                   G1/S transition of mitotic cell cycle*
# 199120  SIC1                   G1/S transition of mitotic cell cycle*
# 199172  CDC4                   G1/S transition of mitotic cell cycle*
# 199191  PTK2                   G1/S transition of mitotic cell cycle*
# 199270  POG1        G1/S-specific transcription in mitotic cell cy...
#
#                                               molfunction  sysname  genenum
# 108                                       protein binding  YGR211W  1082106
# 118                  protein phosphatase type 2C activity  YER089C  1084958
# 434                            molecular function unknown  YBL051C  1084089
# 445         protein-arginine N-methyltransferase activity  YBR133C  1082505
# 466     phosphopantothenoylcysteine decarboxylase acti...  YKR072C  1081300
# ...                                                   ...      ...      ...
# 199116  phosphopantothenoylcysteine decarboxylase acti...  YOR054C  1084698
# 199120                                   protein binding*  YLR079W  1080719
# 199172                                   protein binding*  YFL009W  1080982
# 199191                            protein kinase activity  YJR059W  1082178
# 199270  specific RNA polymerase II transcription facto...  YIL122W  1081544
#
# [2160 rows x 8 columns]

# %%
cycle2['biofunction'].unique()
# Out:
# array(['regulation of progression through cell cycle',
#        'G1/S transition of mitotic cell cycle*',
#        'G2/M transition of mitotic cell cycle*',
#        'regulation of progression through cell cycle*',
#        'G1/S-specific transcription in mitotic cell cycle', 'cell cycle',
#        'G1/S transition of mitotic cell cycle',
#        'regulation of progression through mitotic cell cycle',
#        'G1-specific transcription in mitotic cell cycle', 'cell cycle*',
#        'G2/M-specific transcription in mitotic cell cycle',
#        'cell cycle arrest in response to pheromone',
#        'G1/S-specific transcription in mitotic cell cycle*'], dtype=object)

# %%
cellcycle
# Out:
#                                                      NAME variable  value  \
# 706     PCL2       -- cell cycle -- cyclin-dependent p...    G0.05  -1.19
# 1132    PCL9       -- cell cycle -- cyclin-dependent p...    G0.05  -1.15
# 2740    CLG1       -- cell cycle -- cyclin-dependent p...    G0.05   0.17
# 2771    SCM4       -- cell cycle -- molecular function...    G0.05   0.17
# 2948    PCL5       -- cell cycle -- cyclin-dependent p...    G0.05   2.00
# ...                                                   ...      ...    ...
# 194927  PCL9       -- cell cycle -- cyclin-dependent p...     U0.3   0.13
# 196535  CLG1       -- cell cycle -- cyclin-dependent p...     U0.3   0.03
# 196566  SCM4       -- cell cycle -- molecular function...     U0.3   0.48
# 196743  PCL5       -- cell cycle -- cyclin-dependent p...     U0.3  -1.00
# 198352  PCL1       -- cell cycle -- cyclin-dependent p...     U0.3  -0.28
#
#           genename biofunction  \
# 706     PCL2        cell cycle
# 1132    PCL9        cell cycle
# 2740    CLG1        cell cycle
# 2771    SCM4        cell cycle
# 2948    PCL5        cell cycle
# ...            ...         ...
# 194927  PCL9        cell cycle
# 196535  CLG1        cell cycle
# 196566  SCM4        cell cycle
# 196743  PCL5        cell cycle
# 198352  PCL1        cell cycle
#
#                                               molfunction  sysname  genenum
# 706     cyclin-dependent protein kinase regulator acti...  YDL127W  1082011
# 1132    cyclin-dependent protein kinase regulator acti...  YDL179W  1085191
# 2740    cyclin-dependent protein kinase regulator acti...  YGL215W  1083039
# 2771                           molecular function unknown  YGR049W  1085248
# 2948    cyclin-dependent protein kinase regulator acti...  YHR071W  1083682
# ...                                                   ...      ...      ...
# 194927  cyclin-dependent protein kinase regulator acti...  YDL179W  1085191
# 196535  cyclin-dependent protein kinase regulator acti...  YGL215W  1083039
# 196566                         molecular function unknown  YGR049W  1085248
# 196743  cyclin-dependent protein kinase regulator acti...  YHR071W  1083682
# 198352  cyclin-dependent protein kinase regulator acti...  YNL289W  1082226
#
# [216 rows x 8 columns]

# %% [markdown]
# Next, subset the dataframe again so it only contains cell cycle genes from the glucose treatments "G"
#
# Hint: Consider looking into str.contains https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.contains.html

# %%
cellcycleg=cellcycle[cellcycle['variable'].str.contains('G')]
cellcycleg
# Out:
#                                                     NAME variable  value  \
# 706    PCL2       -- cell cycle -- cyclin-dependent p...    G0.05  -1.19
# 1132   PCL9       -- cell cycle -- cyclin-dependent p...    G0.05  -1.15
# 2740   CLG1       -- cell cycle -- cyclin-dependent p...    G0.05   0.17
# 2771   SCM4       -- cell cycle -- molecular function...    G0.05   0.17
# 2948   PCL5       -- cell cycle -- cyclin-dependent p...    G0.05   2.00
# 4557   PCL1       -- cell cycle -- cyclin-dependent p...    G0.05  -0.64
# 6243   PCL2       -- cell cycle -- cyclin-dependent p...     G0.1  -0.52
# 6669   PCL9       -- cell cycle -- cyclin-dependent p...     G0.1  -0.55
# 8277   CLG1       -- cell cycle -- cyclin-dependent p...     G0.1   0.15
# 8308   SCM4       -- cell cycle -- molecular function...     G0.1  -0.19
# 8485   PCL5       -- cell cycle -- cyclin-dependent p...     G0.1   1.75
# 10094  PCL1       -- cell cycle -- cyclin-dependent p...     G0.1  -0.46
# 11780  PCL2       -- cell cycle -- cyclin-dependent p...    G0.15  -0.55
# 12206  PCL9       -- cell cycle -- cyclin-dependent p...    G0.15   0.29
# 13814  CLG1       -- cell cycle -- cyclin-dependent p...    G0.15   0.01
# 13845  SCM4       -- cell cycle -- molecular function...    G0.15   0.01
# 14022  PCL5       -- cell cycle -- cyclin-dependent p...    G0.15   0.96
# 15631  PCL1       -- cell cycle -- cyclin-dependent p...    G0.15  -0.51
# 17317  PCL2       -- cell cycle -- cyclin-dependent p...     G0.2  -0.33
# 17743  PCL9       -- cell cycle -- cyclin-dependent p...     G0.2   0.38
# 19351  CLG1       -- cell cycle -- cyclin-dependent p...     G0.2  -0.04
# 19382  SCM4       -- cell cycle -- molecular function...     G0.2  -0.07
# 19559  PCL5       -- cell cycle -- cyclin-dependent p...     G0.2   0.01
# 21168  PCL1       -- cell cycle -- cyclin-dependent p...     G0.2  -0.15
# 22854  PCL2       -- cell cycle -- cyclin-dependent p...    G0.25  -0.10
# 23280  PCL9       -- cell cycle -- cyclin-dependent p...    G0.25   0.01
# 24888  CLG1       -- cell cycle -- cyclin-dependent p...    G0.25  -0.06
# 24919  SCM4       -- cell cycle -- molecular function...    G0.25   0.11
# 25096  PCL5       -- cell cycle -- cyclin-dependent p...    G0.25  -0.30
# 26705  PCL1       -- cell cycle -- cyclin-dependent p...    G0.25  -0.05
# 28391  PCL2       -- cell cycle -- cyclin-dependent p...     G0.3   0.03
# 28817  PCL9       -- cell cycle -- cyclin-dependent p...     G0.3   0.09
# 30425  CLG1       -- cell cycle -- cyclin-dependent p...     G0.3  -0.20
# 30456  SCM4       -- cell cycle -- molecular function...     G0.3   0.30
# 30633  PCL5       -- cell cycle -- cyclin-dependent p...     G0.3  -0.31
# 32242  PCL1       -- cell cycle -- cyclin-dependent p...     G0.3  -0.44
#
#          genename biofunction  \
# 706    PCL2        cell cycle
# 1132   PCL9        cell cycle
# 2740   CLG1        cell cycle
# 2771   SCM4        cell cycle
# 2948   PCL5        cell cycle
# 4557   PCL1        cell cycle
# 6243   PCL2        cell cycle
# 6669   PCL9        cell cycle
# 8277   CLG1        cell cycle
# 8308   SCM4        cell cycle
# 8485   PCL5        cell cycle
# 10094  PCL1        cell cycle
# 11780  PCL2        cell cycle
# 12206  PCL9        cell cycle
# 13814  CLG1        cell cycle
# 13845  SCM4        cell cycle
# 14022  PCL5        cell cycle
# 15631  PCL1        cell cycle
# 17317  PCL2        cell cycle
# 17743  PCL9        cell cycle
# 19351  CLG1        cell cycle
# 19382  SCM4        cell cycle
# 19559  PCL5        cell cycle
# 21168  PCL1        cell cycle
# 22854  PCL2        cell cycle
# 23280  PCL9        cell cycle
# 24888  CLG1        cell cycle
# 24919  SCM4        cell cycle
# 25096  PCL5        cell cycle
# 26705  PCL1        cell cycle
# 28391  PCL2        cell cycle
# 28817  PCL9        cell cycle
# 30425  CLG1        cell cycle
# 30456  SCM4        cell cycle
# 30633  PCL5        cell cycle
# 32242  PCL1        cell cycle
#
#                                              molfunction  sysname  genenum
# 706    cyclin-dependent protein kinase regulator acti...  YDL127W  1082011
# 1132   cyclin-dependent protein kinase regulator acti...  YDL179W  1085191
# 2740   cyclin-dependent protein kinase regulator acti...  YGL215W  1083039
# 2771                          molecular function unknown  YGR049W  1085248
# 2948   cyclin-dependent protein kinase regulator acti...  YHR071W  1083682
# 4557   cyclin-dependent protein kinase regulator acti...  YNL289W  1082226
# 6243   cyclin-dependent protein kinase regulator acti...  YDL127W  1082011
# 6669   cyclin-dependent protein kinase regulator acti...  YDL179W  1085191
# 8277   cyclin-dependent protein kinase regulator acti...  YGL215W  1083039
# 8308                          molecular function unknown  YGR049W  1085248
# 8485   cyclin-dependent protein kinase regulator acti...  YHR071W  1083682
# 10094  cyclin-dependent protein kinase regulator acti...  YNL289W  1082226
# 11780  cyclin-dependent protein kinase regulator acti...  YDL127W  1082011
# 12206  cyclin-dependent protein kinase regulator acti...  YDL179W  1085191
# 13814  cyclin-dependent protein kinase regulator acti...  YGL215W  1083039
# 13845                         molecular function unknown  YGR049W  1085248
# 14022  cyclin-dependent protein kinase regulator acti...  YHR071W  1083682
# 15631  cyclin-dependent protein kinase regulator acti...  YNL289W  1082226
# 17317  cyclin-dependent protein kinase regulator acti...  YDL127W  1082011
# 17743  cyclin-dependent protein kinase regulator acti...  YDL179W  1085191
# 19351  cyclin-dependent protein kinase regulator acti...  YGL215W  1083039
# 19382                         molecular function unknown  YGR049W  1085248
# 19559  cyclin-dependent protein kinase regulator acti...  YHR071W  1083682
# 21168  cyclin-dependent protein kinase regulator acti...  YNL289W  1082226
# 22854  cyclin-dependent protein kinase regulator acti...  YDL127W  1082011
# 23280  cyclin-dependent protein kinase regulator acti...  YDL179W  1085191
# 24888  cyclin-dependent protein kinase regulator acti...  YGL215W  1083039
# 24919                         molecular function unknown  YGR049W  1085248
# 25096  cyclin-dependent protein kinase regulator acti...  YHR071W  1083682
# 26705  cyclin-dependent protein kinase regulator acti...  YNL289W  1082226
# 28391  cyclin-dependent protein kinase regulator acti...  YDL127W  1082011
# 28817  cyclin-dependent protein kinase regulator acti...  YDL179W  1085191
# 30425  cyclin-dependent protein kinase regulator acti...  YGL215W  1083039
# 30456                         molecular function unknown  YGR049W  1085248
# 30633  cyclin-dependent protein kinase regulator acti...  YHR071W  1083682
# 32242  cyclin-dependent protein kinase regulator acti...  YNL289W  1082226

# %% [markdown]
# Write the subsetted file out to a csv - and open it in excel or google sheets to examine it and see if you did it right.  Screenshot the result.

# %%
cellcycleg.to_csv('test.csv')

# %% [markdown]
# YAY you're all finished and are now super extra awesome at tidying data!!
